# %%
import pandas as pd
import os
import tiktoken
from openai import OpenAI
from langchain.text_splitter import RecursiveCharacterTextSplitter
from dotenv import load_dotenv

load_dotenv()

openai = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

DOMAIN = "developer.mozilla.org"

# %%
tokenizer = tiktoken.get_encoding("cl100k_base")

df = pd.read_csv("../processed/scraped.csv", index_col=0)
df.columns = ["title", "text"]
print(f"Len of scraped is {len(df)}")
df["n_tokens"] = df.text.apply(lambda x: len(tokenizer.encode(x)))

chunk_size = 1000  # max number of tokens

text_splitter = RecursiveCharacterTextSplitter(
    length_function = len,  
    chunk_size = chunk_size,
    chunk_overlap  = 0,  # No overlap between chunks
    add_start_index = False,  # We don't need start index in this case
)

shortened = []

for row in df.iterrows():
    if row[1]["text"] is None:
        continue
    if row[1]["n_tokens"] > chunk_size:
        print(f"Chunking row {row[1]['title']}")
        chunks = text_splitter.create_documents([row[1]["text"]])
        for chunk in chunks:
            shortened.append(chunk.page_content)
    else:
        shortened.append(row[1]["text"])

df = pd.DataFrame(shortened, columns=["text"])
df["n_tokens"] = df.text.apply(lambda x: len(tokenizer.encode(x)))
# Out:
# Len of scraped is 268
# Chunking row developer.mozilla.org/en-US/docs/Web/HTML/Attributes
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators#assignment/operators
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Lexical/grammar#exponential
# Chunking row developer.mozilla.org/en-US/docs/Web/API/HTMLElement/dragover/event
# Chunking row developer.mozilla.org/en-US/docs/Web/Security/Referer/header:/privacy/and/security/concerns
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/const#description
# Chunking row developer.mozilla.org/en-US/docs/Web/Accessibility/Understanding/WCAG/Perceivable#guideline/1.4/make/it/easier/for/users/to/see/and/hear/content/including/separating/foreground/from/background
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/Value/definition/syntax#single/bar
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Node/removeChild
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global/Objects/Object/toLocaleString
# Chunking row developer.mozilla.org/en-US/docs/Web/HTML/Content/categories#phrasing/content
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/Pseudo-classes
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Grammar/and/types#constants
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Element/webkitmouseforcechanged/event
# Chunking row developer.mozilla.org/en-US/docs/Web/HTML/Element/video#loop
# Chunking row developer.mozilla.org/en-US/docs/Web/API/XMLHttpRequest/send
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Data/structures#data/property
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Iteration/protocols
# Chunking row developer.mozilla.org/en-US/docs/Web/API/CanvasRenderingContext2D/lineTo
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Document/dragenter/event
# Chunking row developer.mozilla.org/en-US/docs/Learn/Tools/and/testing/Cross/browser/testing/Accessibility#using/native/keyboard/accessibility
# Chunking row developer.mozilla.org/en-US/docs/Learn/Common/questions/Tools/and/setup/Upload/files/to/a/web/server
# Chunking row developer.mozilla.org/en-US/docs/Web/API/CanvasRenderingContext2D/clip
# Chunking row developer.mozilla.org/en-US/docs/Web/HTTP/CORS#simple/requests
# Chunking row developer.mozilla.org/en-US/docs/Web/API/HTMLMediaElement/networkState
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Event/Comparison/of/Event/Targets
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Document/Object/Model#svg/interfaces
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/Pseudo-classes#specifications
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/padding
# Chunking row developer.mozilla.org/en-US/docs/Web/Accessibility/Understanding/WCAG/Perceivable
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global/Objects/Number/isInteger
# Chunking row developer.mozilla.org/en-US/docs/Web/HTML/Element/img#intrinsicsize
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/Pseudo-elements
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/Cascade
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Node/isDefaultNamespace
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/Selector/list#invalid/selector/list
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/CSS/Selectors#relative/selector
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Canvas/API/Manipulating/video/using/canvas
# Chunking row developer.mozilla.org/en-US/docs/Web/Accessibility/Understanding/WCAG/Understandable
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Grammar/and/types#array/literals
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Document/Object/Model/Examples#example/7/displaying/event/object/properties
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Attr/localName
# Chunking row developer.mozilla.org/en-US/docs/Web/API/CanvasRenderingContext2D/createLinearGradient
# Chunking row developer.mozilla.org/en-US/docs/Web/API/KeyboardEvent/keyCode
# Chunking row developer.mozilla.org/en-US/docs/Web/Performance
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global/Objects/Object/getOwnPropertyDescriptors
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Navigator/languages
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global/Objects/Array/Array#array/literal/notation
# Chunking row developer.mozilla.org/en-US/docs/Web/API/HTMLMediaElement/src
# Chunking row developer.mozilla.org/en-US/docs/Web/Security/Transport/Layer/Security
# Chunking row developer.mozilla.org/en-US/docs/Web/API/MediaSource/isTypeSupported/static
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/var#description
# Chunking row developer.mozilla.org/en-US/docs/Learn/HTML/Multimedia/and/embedding/Video/and/audio/content/Test/your/skills:/Multimedia/and/embedding
# Chunking row developer.mozilla.org/en-US/docs/Web/HTTP/Methods/GET
# Chunking row developer.mozilla.org/en-US/docs/Web/API/HTMLMediaElement/autoplay
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Lexical/grammar#string/literals
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Grammar/and/types#declarations
# Chunking row developer.mozilla.org/en-US/docs/Web/API/CanvasRenderingContext2D/fontVariantCaps
# Chunking row developer.mozilla.org/en-US/docs/Web/Performance/Critical/rendering/path
# Chunking row developer.mozilla.org/en-US/docs/Web/SVG/Tutorial
# Chunking row developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Set-Cookie#samesitesamesite-value
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Canvas/API/Tutorial/Compositing
# Chunking row developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Sec-Fetch-Site
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global/Objects/Number/toString
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/Pseudo-elements#specifications
# Chunking row developer.mozilla.org/en-US/docs/Learn/HTML/Multimedia/and/embedding/Images/in/HTML/Test/your/skills:/HTML/images
# Chunking row developer.mozilla.org/en-US/docs/Web/API/DOMImplementation/createHTMLDocument
# Chunking row developer.mozilla.org/en-US/docs/Web/Guide
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Node/compareDocumentPosition
# Chunking row developer.mozilla.org/en-US/docs/Web/Media/Formats/Video/codecs
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global/Objects/Object/defineProperty
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Operator/precedence#short-circuiting
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Document/drop/event
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/font-variant-caps#accessibility/concerns
# Chunking row developer.mozilla.org/en-US/docs/Web/HTML/Element/u
# Chunking row developer.mozilla.org/en-US/docs/Web/API/KeyboardEvent/initKeyEvent
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/CSS/box/model/Introduction/to/the/CSS/box/model#padding/area
# Chunking row developer.mozilla.org/en-US/docs/Learn/JavaScript/Building/blocks/Events
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/for
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global/Objects/Number/isSafeInteger
# Chunking row developer.mozilla.org/en-US/docs/Web/SVG/Attribute
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Document/readystatechange/event
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Operators/Property/accessors#bracket/notation
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Document/childElementCount
# Chunking row developer.mozilla.org/en-US/docs/Learn/Accessibility/Multimedia#audio/transcripts
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/Selector/list#forgiving/selector/list
# Chunking row developer.mozilla.org/en-US/docs/Learn/Accessibility/Multimedia#other/multimedia/content
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Window/scrollTo
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global/Objects/Array/slice
# Chunking row developer.mozilla.org/en-US/docs/Web/Progressive/web/apps/Responsive/responsive/design/building/blocks
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Attr/namespaceURI
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global/Objects/Object/getOwnPropertyNames
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Document/dragleave/event
# Chunking row developer.mozilla.org/en-US/docs/Web/API/HTML/Drag/and/Drop/API/Recommended/drag/types
# Chunking row developer.mozilla.org/en-US/docs/Learn/Accessibility/HTML#meaningful/text/labels
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/Selector/list#selector/list
# Chunking row developer.mozilla.org/en-US/docs/Learn/Tools/and/testing/Cross/browser/testing/HTML/and/CSS#ie/conditional/comments
# Chunking row developer.mozilla.org/en-US/docs/Web/API/HTMLTableElement#methods
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Global/Objects/Number/Number
# Chunking row developer.mozilla.org/en-US/docs/Web/CSS/At-rule
# Chunking row developer.mozilla.org/en-US/docs/Web/SVG/Attribute/Events#animation/event/attributes
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Data/structures#accessor/property
# Chunking row developer.mozilla.org/en-US/docs/Learn/Common/questions/Design/and/accessibility/What/is/accessibility
# Chunking row developer.mozilla.org/en-US/docs/Web/HTML/Element/table#frame
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Window/beforeunload/event
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Element/scrollTo
# Chunking row developer.mozilla.org/en-US/docs/Web/SVG/Element/svg
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Node/lookupPrefix
# Chunking row developer.mozilla.org/en-US/docs/Web/HTML/Element/style
# Chunking row developer.mozilla.org/en-US/docs/Web/SVG/Attribute/method
# Chunking row developer.mozilla.org/en-US/docs/Web/Media/Formats/Image/types#webp/image
# Chunking row developer.mozilla.org/en-US/docs/Web/API/Navigator/getAutoplayPolicy
# Chunking row developer.mozilla.org/en-US/docs/Learn/Common/questions/Design/and/accessibility
# Chunking row developer.mozilla.org/en-US/docs/Web/API/File/API/Using/files/from/web/applications#example/using/object/urls/to/display/images
# Chunking row developer.mozilla.org/en-US/docs/Web/API/DocumentFragment/getElementById
# Chunking row developer.mozilla.org/en-US/docs/Web/JavaScript/Reference/Statements/let#temporal/dead/zone/tdz

# %%
len(df)

# %%
def create_embedding(x):
    return openai.embeddings.create(
        input=x, model='text-embedding-3-small').data[0].embedding

df_embeds = pd.DataFrame(shortened, columns=["text"])
df_embeds["n_tokens"] = df.text.apply(lambda x: len(tokenizer.encode(x)))
df_embeds['embeddings'] = ""
print(f"Total rows to process: {len(df)}")
for i, row in df.iterrows():
    print(f"Processing row {i}")
    embed_vector = create_embedding(row['text'])
    df_embeds['embeddings'][i] = embed_vector

# %%
df_embeds.to_csv("../processed/embeddings.csv")
